# %%
# json
import json

# math
import math

# pandas
import pandas as pd
from pandas import Series,DataFrame

# numpy, matplotlib, seaborn
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# Random libraries and seeds:
import random
random.seed(2)
np.random.seed(2)

pd.set_option('display.max_columns', None)

# %%
# From: http://scikit-learn.org/stable/auto_examples/model_selection/plot_confusion_matrix.html
import itertools
from sklearn.metrics import confusion_matrix

def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    #print(cm)

    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, cm[i, j],
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# %%
import sklearn.model_selection as mds
from sklearn.ensemble import RandomForestClassifier
from sklearn.multiclass import OneVsRestClassifier

# %%
def get_accuracy(number_groups, region):
    
    #print("datasets/%d/%s.csv" % (number_groups, region))
    data = pd.read_csv("datasets/%d/%s.csv" % (number_groups, region))
    
    data = pd.get_dummies(data, columns = ["attacktype1_txt",
                     "targtype1_txt",
                     "weaptype1_txt",
                     "natlty1_txt",
                     "weaptype1_txt",
                     "weapsubtype1_txt"])
    
    train, validate, test = np.split(data.sample(frac=1), [int(.6*len(data)), int(.8*len(data))])
    
    X_train = train.drop(["gname", "region_txt"], axis=1)
    Y_train = train["gname"]
    
    X_val = validate.drop(["gname", "region_txt"], axis=1)
    Y_val = validate["gname"]
    
    X_test = test.drop(["gname", "region_txt"], axis=1)
    Y_test = test["gname"]
    
    # 70% train, 30% test
    #msk = np.random.rand(len(data_region)) < 0.7
    
    #X_train = X[msk]
    #Y_train = Y[msk]
    
    #X_test = X[~msk]
    #Y_test = Y[~msk]
    
    Y_pred = OneVsRestClassifier(RandomForestClassifier(random_state=2)).fit(X_train, Y_train).predict(X_val)
    
    return((sum(Y_pred == Y_val) / len(Y_pred))) # return accuracy

    #print("%s, %d/%d => %s" % (region, sum(Y_pred == Y_val), len(Y_pred), (sum(Y_pred == Y_val) / len(Y_pred))))
    #print(data_region["gname"].value_counts())
    #print("\n")

# %%
regions = ["Australasia & Oceania",
             "Central America & Caribbean",
             "Central Asia",
             "East Asia",
             "Eastern Europe",
             "Middle East & North Africa",
             "North America",
             "South America",
             "South Asia",
             "Southeast Asia",
             "Sub-Saharan Africa",
             "Western Europe"]

results = pd.DataFrame(columns=('region', 'groups', 'accuracy'))
i = 0

for region in regions:
    for n_groups in range(50):
        accuracy = get_accuracy(n_groups + 1, region)
        results.loc[i] = [region, n_groups + 1, accuracy]
        print("Did %s n%d" % (region, n_groups + 1))
        i = i + 1
# Out:
# Did Australasia & Oceania n1
# Did Australasia & Oceania n2
# Did Australasia & Oceania n3
# Did Australasia & Oceania n4
# Did Australasia & Oceania n5
# Did Australasia & Oceania n6
# Did Australasia & Oceania n7
# Did Australasia & Oceania n8
# Did Australasia & Oceania n9
# Did Australasia & Oceania n10
# Did Australasia & Oceania n11
# Did Australasia & Oceania n12
# Did Australasia & Oceania n13
# Did Australasia & Oceania n14
# Did Australasia & Oceania n15
# Did Australasia & Oceania n16
# Did Australasia & Oceania n17
# Did Australasia & Oceania n18
# Did Australasia & Oceania n19
# Did Australasia & Oceania n20
# Did Australasia & Oceania n21
# Did Australasia & Oceania n22
# Did Australasia & Oceania n23
# Did Australasia & Oceania n24
# Did Australasia & Oceania n25
# Did Australasia & Oceania n26
# Did Australasia & Oceania n27
# Did Australasia & Oceania n28
# Did Australasia & Oceania n29
# Did Australasia & Oceania n30
# Did Australasia & Oceania n31
# Did Australasia & Oceania n32
# Did Australasia & Oceania n33
# Did Australasia & Oceania n34
# Did Australasia & Oceania n35
# Did Australasia & Oceania n36
# Did Australasia & Oceania n37
# Did Australasia & Oceania n38
# Did Australasia & Oceania n39
# Did Australasia & Oceania n40
# Did Australasia & Oceania n41
# Did Australasia & Oceania n42
# Did Australasia & Oceania n43
# Did Australasia & Oceania n44
# Did Australasia & Oceania n45
# Did Australasia & Oceania n46
# Did Australasia & Oceania n47
# Did Australasia & Oceania n48
# Did Australasia & Oceania n49
# Did Australasia & Oceania n50
# Did Central America & Caribbean n1
# Did Central America & Caribbean n2
# Did Central America & Caribbean n3
# Did Central America & Caribbean n4
# Did Central America & Caribbean n5
# Did Central America & Caribbean n6
# Did Central America & Caribbean n7
# Did Central America & Caribbean n8
# Did Central America & Caribbean n9
# Did Central America & Caribbean n10
# Did Central America & Caribbean n11
# Did Central America & Caribbean n12
# Did Central America & Caribbean n13
# Did Central America & Caribbean n14
# Did Central America & Caribbean n15
# Did Central America & Caribbean n16
# Did Central America & Caribbean n17
# Did Central America & Caribbean n18
# Did Central America & Caribbean n19
# Did Central America & Caribbean n20
# Did Central America & Caribbean n21
# Did Central America & Caribbean n22
# Did Central America & Caribbean n23
# Did Central America & Caribbean n24
# Did Central America & Caribbean n25
# Did Central America & Caribbean n26
# Did Central America & Caribbean n27
# Did Central America & Caribbean n28
# Did Central America & Caribbean n29
# Did Central America & Caribbean n30
# Did Central America & Caribbean n31
# Did Central America & Caribbean n32
# Did Central America & Caribbean n33
# Did Central America & Caribbean n34
# Did Central America & Caribbean n35
# Did Central America & Caribbean n36
# Did Central America & Caribbean n37
# Did Central America & Caribbean n38
# Did Central America & Caribbean n39
# Did Central America & Caribbean n40
# Did Central America & Caribbean n41
# Did Central America & Caribbean n42
# Did Central America & Caribbean n43
# Did Central America & Caribbean n44
# Did Central America & Caribbean n45
# Did Central America & Caribbean n46
# Did Central America & Caribbean n47
# Did Central America & Caribbean n48
# Did Central America & Caribbean n49
# Did Central America & Caribbean n50
# Did Central Asia n1
# Did Central Asia n2
# Did Central Asia n3
# Did Central Asia n4
# Did Central Asia n5
# Did Central Asia n6
# Did Central Asia n7
# Did Central Asia n8
# Did Central Asia n9
# Did Central Asia n10
# Did Central Asia n11
# Did Central Asia n12
# Did Central Asia n13
# Did Central Asia n14
# Did Central Asia n15
# Did Central Asia n16
# Did Central Asia n17
# Did Central Asia n18
# Did Central Asia n19
# Did Central Asia n20
# Did Central Asia n21
# Did Central Asia n22
# Did Central Asia n23
# Did Central Asia n24
# Did Central Asia n25
# Did Central Asia n26
# Did Central Asia n27
# Did Central Asia n28
# Did Central Asia n29
# Did Central Asia n30
# Did Central Asia n31
# Did Central Asia n32
# Did Central Asia n33
# Did Central Asia n34
# Did Central Asia n35
# Did Central Asia n36
# Did Central Asia n37
# Did Central Asia n38
# Did Central Asia n39
# Did Central Asia n40
# Did Central Asia n41
# Did Central Asia n42
# Did Central Asia n43
# Did Central Asia n44
# Did Central Asia n45
# Did Central Asia n46
# Did Central Asia n47
# Did Central Asia n48
# Did Central Asia n49
# Did Central Asia n50
# Did East Asia n1
# Did East Asia n2
# Did East Asia n3
# Did East Asia n4
# Did East Asia n5
# Did East Asia n6
# Did East Asia n7
# Did East Asia n8
# Did East Asia n9
# Did East Asia n10
# Did East Asia n11
# Did East Asia n12
# Did East Asia n13
# Did East Asia n14
# Did East Asia n15
# Did East Asia n16
# Did East Asia n17
# Did East Asia n18
# Did East Asia n19
# Did East Asia n20
# Did East Asia n21
# Did East Asia n22
# Did East Asia n23
# Did East Asia n24
# Did East Asia n25
# Did East Asia n26
# Did East Asia n27
# Did East Asia n28
# Did East Asia n29
# Did East Asia n30
# Did East Asia n31
# Did East Asia n32
# Did East Asia n33
# Did East Asia n34
# Did East Asia n35
# Did East Asia n36
# Did East Asia n37
# Did East Asia n38
# Did East Asia n39
# Did East Asia n40
# Did East Asia n41
# Did East Asia n42
# Did East Asia n43
# Did East Asia n44
# Did East Asia n45
# Did East Asia n46
# Did East Asia n47
# Did East Asia n48
# Did East Asia n49
# Did East Asia n50
# Did Eastern Europe n1
# Did Eastern Europe n2
# Did Eastern Europe n3
# Did Eastern Europe n4
# Did Eastern Europe n5
# Did Eastern Europe n6
# Did Eastern Europe n7
# Did Eastern Europe n8
# Did Eastern Europe n9
# Did Eastern Europe n10
# Did Eastern Europe n11
# Did Eastern Europe n12
# Did Eastern Europe n13
# Did Eastern Europe n14
# Did Eastern Europe n15
# Did Eastern Europe n16
# Did Eastern Europe n17
# Did Eastern Europe n18
# Did Eastern Europe n19
# Did Eastern Europe n20
# Did Eastern Europe n21
# Did Eastern Europe n22
# Did Eastern Europe n23
# Did Eastern Europe n24
# Did Eastern Europe n25
# Did Eastern Europe n26
# Did Eastern Europe n27
# Did Eastern Europe n28
# Did Eastern Europe n29
# Did Eastern Europe n30
# Did Eastern Europe n31
# Did Eastern Europe n32
# Did Eastern Europe n33
# Did Eastern Europe n34
# Did Eastern Europe n35
# Did Eastern Europe n36
# Did Eastern Europe n37
# Did Eastern Europe n38
# Did Eastern Europe n39
# Did Eastern Europe n40
# Did Eastern Europe n41
# Did Eastern Europe n42
# Did Eastern Europe n43
# Did Eastern Europe n44
# Did Eastern Europe n45
# Did Eastern Europe n46
# Did Eastern Europe n47
# Did Eastern Europe n48
# Did Eastern Europe n49
# Did Eastern Europe n50
# Did Middle East & North Africa n1
# Did Middle East & North Africa n2
# Did Middle East & North Africa n3
# Did Middle East & North Africa n4
# Did Middle East & North Africa n5
# Did Middle East & North Africa n6
# Did Middle East & North Africa n7
# Did Middle East & North Africa n8
# Did Middle East & North Africa n9
# Did Middle East & North Africa n10
# Did Middle East & North Africa n11
# Did Middle East & North Africa n12
# Did Middle East & North Africa n13
# Did Middle East & North Africa n14
# Did Middle East & North Africa n15
# Did Middle East & North Africa n16
# Did Middle East & North Africa n17
# Did Middle East & North Africa n18
# Did Middle East & North Africa n19
# Did Middle East & North Africa n20
# Did Middle East & North Africa n21
# Did Middle East & North Africa n22
# Did Middle East & North Africa n23
# Did Middle East & North Africa n24
# Did Middle East & North Africa n25
# Did Middle East & North Africa n26
# Did Middle East & North Africa n27
# Did Middle East & North Africa n28
# Did Middle East & North Africa n29
# Did Middle East & North Africa n30
# Did Middle East & North Africa n31
# Did Middle East & North Africa n32
# Did Middle East & North Africa n33
# Did Middle East & North Africa n34
# Did Middle East & North Africa n35
# Did Middle East & North Africa n36
# Did Middle East & North Africa n37
# Did Middle East & North Africa n38
# Did Middle East & North Africa n39
# Did Middle East & North Africa n40
# Did Middle East & North Africa n41
# Did Middle East & North Africa n42
# Did Middle East & North Africa n43
# Did Middle East & North Africa n44
# Did Middle East & North Africa n45
# Did Middle East & North Africa n46
# Did Middle East & North Africa n47
# Did Middle East & North Africa n48
# Did Middle East & North Africa n49
# Did Middle East & North Africa n50
# Did North America n1
# Did North America n2
# Did North America n3
# Did North America n4
# Did North America n5
# Did North America n6
# Did North America n7
# Did North America n8
# Did North America n9
# Did North America n10
# Did North America n11
# Did North America n12
# Did North America n13
# Did North America n14
# Did North America n15
# Did North America n16
# Did North America n17
# Did North America n18
# Did North America n19
# Did North America n20
# Did North America n21
# Did North America n22
# Did North America n23
# Did North America n24
# Did North America n25
# Did North America n26
# Did North America n27
# Did North America n28
# Did North America n29
# Did North America n30
# Did North America n31
# Did North America n32
# Did North America n33
# Did North America n34
# Did North America n35
# Did North America n36
# Did North America n37
# Did North America n38
# Did North America n39
# Did North America n40
# Did North America n41
# Did North America n42
# Did North America n43
# Did North America n44
# Did North America n45
# Did North America n46
# Did North America n47
# Did North America n48
# Did North America n49
# Did North America n50
# Did South America n1
# Did South America n2
# Did South America n3
# Did South America n4
# Did South America n5
# Did South America n6
# Did South America n7
# Did South America n8
# Did South America n9
# Did South America n10
# Did South America n11
# Did South America n12
# Did South America n13
# Did South America n14
# Did South America n15
# Did South America n16
# Did South America n17
# Did South America n18
# Did South America n19
# Did South America n20
# Did South America n21
# Did South America n22
# Did South America n23
# Did South America n24
# Did South America n25
# Did South America n26
# Did South America n27
# Did South America n28
# Did South America n29
# Did South America n30
# Did South America n31
# Did South America n32
# Did South America n33
# Did South America n34
# Did South America n35
# Did South America n36
# Did South America n37
# Did South America n38
# Did South America n39
# Did South America n40
# Did South America n41
# Did South America n42
# Did South America n43
# Did South America n44
# Did South America n45
# Did South America n46
# Did South America n47
# Did South America n48
# Did South America n49
# Did South America n50
# Did South Asia n1
# Did South Asia n2
# Did South Asia n3
# Did South Asia n4
# Did South Asia n5
# Did South Asia n6
# Did South Asia n7
# Did South Asia n8
# Did South Asia n9
# Did South Asia n10
# Did South Asia n11
# Did South Asia n12
# Did South Asia n13
# Did South Asia n14
# Did South Asia n15
# Did South Asia n16
# Did South Asia n17
# Did South Asia n18
# Did South Asia n19
# Did South Asia n20
# Did South Asia n21
# Did South Asia n22
# Did South Asia n23
# Did South Asia n24
# Did South Asia n25
# Did South Asia n26
# Did South Asia n27
# Did South Asia n28
# Did South Asia n29
# Did South Asia n30
# Did South Asia n31
# Did South Asia n32
# Did South Asia n33
# Did South Asia n34
# Did South Asia n35
# Did South Asia n36
# Did South Asia n37
# Did South Asia n38
# Did South Asia n39
# Did South Asia n40
# Did South Asia n41
# Did South Asia n42
# Did South Asia n43
# Did South Asia n44
# Did South Asia n45
# Did South Asia n46
# Did South Asia n47
# Did South Asia n48
# Did South Asia n49
# Did South Asia n50
# Did Southeast Asia n1
# Did Southeast Asia n2
# Did Southeast Asia n3
# Did Southeast Asia n4
# Did Southeast Asia n5
# Did Southeast Asia n6
# Did Southeast Asia n7
# Did Southeast Asia n8
# Did Southeast Asia n9
# Did Southeast Asia n10
# Did Southeast Asia n11
# Did Southeast Asia n12
# Did Southeast Asia n13
# Did Southeast Asia n14
# Did Southeast Asia n15
# Did Southeast Asia n16
# Did Southeast Asia n17
# Did Southeast Asia n18
# Did Southeast Asia n19
# Did Southeast Asia n20
# Did Southeast Asia n21
# Did Southeast Asia n22
# Did Southeast Asia n23
# Did Southeast Asia n24
# Did Southeast Asia n25
# Did Southeast Asia n26
# Did Southeast Asia n27
# Did Southeast Asia n28
# Did Southeast Asia n29
# Did Southeast Asia n30
# Did Southeast Asia n31
# Did Southeast Asia n32
# Did Southeast Asia n33
# Did Southeast Asia n34
# Did Southeast Asia n35
# Did Southeast Asia n36
# Did Southeast Asia n37
# Did Southeast Asia n38
# Did Southeast Asia n39
# Did Southeast Asia n40
# Did Southeast Asia n41
# Did Southeast Asia n42
# Did Southeast Asia n43
# Did Southeast Asia n44
# Did Southeast Asia n45
# Did Southeast Asia n46
# Did Southeast Asia n47
# Did Southeast Asia n48
# Did Southeast Asia n49
# Did Southeast Asia n50
# Did Sub-Saharan Africa n1
# Did Sub-Saharan Africa n2
# Did Sub-Saharan Africa n3
# Did Sub-Saharan Africa n4
# Did Sub-Saharan Africa n5
# Did Sub-Saharan Africa n6
# Did Sub-Saharan Africa n7
# Did Sub-Saharan Africa n8
# Did Sub-Saharan Africa n9
# Did Sub-Saharan Africa n10
# Did Sub-Saharan Africa n11
# Did Sub-Saharan Africa n12
# Did Sub-Saharan Africa n13
# Did Sub-Saharan Africa n14
# Did Sub-Saharan Africa n15
# Did Sub-Saharan Africa n16
# Did Sub-Saharan Africa n17
# Did Sub-Saharan Africa n18
# Did Sub-Saharan Africa n19
# Did Sub-Saharan Africa n20
# Did Sub-Saharan Africa n21
# Did Sub-Saharan Africa n22
# Did Sub-Saharan Africa n23
# Did Sub-Saharan Africa n24
# Did Sub-Saharan Africa n25
# Did Sub-Saharan Africa n26
# Did Sub-Saharan Africa n27
# Did Sub-Saharan Africa n28
# Did Sub-Saharan Africa n29
# Did Sub-Saharan Africa n30
# Did Sub-Saharan Africa n31
# Did Sub-Saharan Africa n32
# Did Sub-Saharan Africa n33
# Did Sub-Saharan Africa n34
# Did Sub-Saharan Africa n35
# Did Sub-Saharan Africa n36
# Did Sub-Saharan Africa n37
# Did Sub-Saharan Africa n38
# Did Sub-Saharan Africa n39
# Did Sub-Saharan Africa n40
# Did Sub-Saharan Africa n41
# Did Sub-Saharan Africa n42
# Did Sub-Saharan Africa n43
# Did Sub-Saharan Africa n44
# Did Sub-Saharan Africa n45
# Did Sub-Saharan Africa n46
# Did Sub-Saharan Africa n47
# Did Sub-Saharan Africa n48
# Did Sub-Saharan Africa n49
# Did Sub-Saharan Africa n50
# Did Western Europe n1
# Did Western Europe n2
# Did Western Europe n3
# Did Western Europe n4
# Did Western Europe n5
# Did Western Europe n6
# Did Western Europe n7
# Did Western Europe n8
# Did Western Europe n9
# Did Western Europe n10
# Did Western Europe n11
# Did Western Europe n12
# Did Western Europe n13
# Did Western Europe n14
# Did Western Europe n15
# Did Western Europe n16
# Did Western Europe n17
# Did Western Europe n18
# Did Western Europe n19
# Did Western Europe n20
# Did Western Europe n21
# Did Western Europe n22
# Did Western Europe n23
# Did Western Europe n24
# Did Western Europe n25
# Did Western Europe n26
# Did Western Europe n27
# Did Western Europe n28
# Did Western Europe n29
# Did Western Europe n30
# Did Western Europe n31
# Did Western Europe n32
# Did Western Europe n33
# Did Western Europe n34
# Did Western Europe n35
# Did Western Europe n36
# Did Western Europe n37
# Did Western Europe n38
# Did Western Europe n39
# Did Western Europe n40
# Did Western Europe n41
# Did Western Europe n42
# Did Western Europe n43
# Did Western Europe n44
# Did Western Europe n45
# Did Western Europe n46
# Did Western Europe n47
# Did Western Europe n48
# Did Western Europe n49
# Did Western Europe n50

# %%
results
# Out:
#                          region  groups  accuracy
# 0         Australasia & Oceania     1.0  1.000000
# 1         Australasia & Oceania     2.0  0.750000
# 2         Australasia & Oceania     3.0  0.916667
# 3   Central America & Caribbean     1.0  0.970130
# 4   Central America & Caribbean     2.0  0.938961
# 5   Central America & Caribbean     3.0  0.944156
# 6                  Central Asia     1.0  0.900000
# 7                  Central Asia     2.0  0.800000
# 8                  Central Asia     3.0  0.700000
# 9                     East Asia     1.0  0.937500
# 10                    East Asia     2.0  0.750000
# 11                    East Asia     3.0  0.875000
# 12               Eastern Europe     1.0  0.906977
# 13               Eastern Europe     2.0  0.860465
# 14               Eastern Europe     3.0  0.697674
# 15   Middle East & North Africa     1.0  0.972810
# 16   Middle East & North Africa     2.0  0.939577
# 17   Middle East & North Africa     3.0  0.939577
# 18                North America     1.0  0.915179
# 19                North America     2.0  0.857143
# 20                North America     3.0  0.812500
# 21                South America     1.0  0.948553
# 22                South America     2.0  0.856684
# 23                South America     3.0  0.813045
# 24                   South Asia     1.0  0.970728
# 25                   South Asia     2.0  0.941885
# 26                   South Asia     3.0  0.930693
# 27               Southeast Asia     1.0  0.844444
# 28               Southeast Asia     2.0  0.801481
# 29               Southeast Asia     3.0  0.786667
# 30           Sub-Saharan Africa     1.0  0.991079
# 31           Sub-Saharan Africa     2.0  0.972346
# 32           Sub-Saharan Africa     3.0  0.961641
# 33               Western Europe     1.0  0.937893
# 34               Western Europe     2.0  0.875087
# 35               Western Europe     3.0  0.827634

# %%
plt.rcParams['figure.figsize']=(10,10)
ax = sns.pointplot(x="groups", y="accuracy", hue="region", data=results)
